# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
import string
import shap

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.impute import SimpleImputer
from sklearn.feature_extraction.text import TfidfVectorizer

from sklearn.ensemble import RandomForestClassifier, HistGradientBoostingClassifier, VotingClassifier

from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    classification_report, confusion_matrix, roc_auc_score
)

from sklearn.preprocessing import label_binarize
from sklearn.model_selection import GridSearchCV

# %%
# Load the dataset with low_memory=False
df = pd.read_csv(r"C:\Users\Lokesh Patra\Documents\Projects\Major Project\cresci-2017.csv\cresci-2017\sytnth\final_dataset.csv", low_memory=False)

# %%
# Step 2: Preprocessing
# Fill missing values
df.fillna("missing", inplace=True)
# Out:
# C:\Users\Lokesh Patra\AppData\Local\Temp\ipykernel_2196\3648774771.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'missing' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.fillna("missing", inplace=True)

# %%
# --- STEP 1: Initial Cleanup ---

# Drop duplicates if any
df.drop_duplicates(inplace=True)

# Lowercase column names (for consistency)
df.columns = df.columns.str.lower()

# Drop exact duplicate columns
df = df.loc[:, ~df.columns.duplicated()]

# Convert date columns to datetime
date_cols = ['created_at_x', 'created_at_y', 'updated_x', 'updated_y', 
             'timestamp_x', 'timestamp_y', 'crawled_at_x', 'crawled_at_y']
date_format = "%Y-%m-%d %H:%M:%S"  # Specify format if known
for col in date_cols:
    if col in df.columns:
        df[col] = pd.to_datetime(df[col], format=date_format, errors='coerce')

# Drop columns with all missing values
df = df.dropna(how='all', axis=1)

# %%
# --- STEP 2: Handle Missing Values ---
# Separate numerical and categorical columns
num_cols = df.select_dtypes(include=['float64', 'int64']).columns.tolist()
cat_cols = df.select_dtypes(include=['object', 'bool']).columns.tolist()

# Impute numerical columns
imputer_num = SimpleImputer(strategy="median")
valid_num_cols = [col for col in num_cols if df[col].notna().sum() > 0]
if valid_num_cols:
    df[valid_num_cols] = imputer_num.fit_transform(df[valid_num_cols])

# Impute categorical columns
imputer_cat = SimpleImputer(strategy="most_frequent")
valid_cat_cols = [col for col in cat_cols if df[col].notna().sum() > 0]
if valid_cat_cols:
    df[valid_cat_cols] = imputer_cat.fit_transform(df[valid_cat_cols])

# --- STEP 3: Validate ---
# Ensure column lengths match
df = df.loc[:, df.columns]

print("Data preprocessing completed successfully!")
# Out:
# Data preprocessing completed successfully!

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 396027 entries, 0 to 396026
# Data columns (total 75 columns):
#  #   Column                              Non-Null Count   Dtype
# ---  ------                              --------------   -----
#  0   user_id                             396027 non-null  float64
#  1   name                                396027 non-null  object
#  2   screen_name                         396027 non-null  object
#  3   statuses_count                      396027 non-null  float64
#  4   followers_count                     396027 non-null  float64
#  5   friends_count                       396027 non-null  float64
#  6   favourites_count                    396027 non-null  float64
#  7   listed_count                        396027 non-null  float64
#  8   created_at_x                        396027 non-null  datetime64[ns]
#  9   url                                 396027 non-null  object
#  10  lang                                396027 non-null  object
#  11  time_zone                           396027 non-null  object
#  12  location                            396027 non-null  object
#  13  default_profile                     396027 non-null  object
#  14  default_profile_image               396027 non-null  object
#  15  geo_enabled                         396027 non-null  object
#  16  profile_image_url                   396027 non-null  object
#  17  profile_banner_url                  396027 non-null  object
#  18  profile_use_background_image        396027 non-null  object
#  19  profile_background_image_url_https  396027 non-null  object
#  20  profile_text_color                  396027 non-null  object
#  21  profile_image_url_https             396027 non-null  object
#  22  profile_sidebar_border_color        396027 non-null  object
#  23  profile_background_tile             396027 non-null  object
#  24  profile_sidebar_fill_color          396027 non-null  object
#  25  profile_background_image_url        396027 non-null  object
#  26  profile_background_color            396027 non-null  object
#  27  profile_link_color                  396027 non-null  object
#  28  utc_offset                          396027 non-null  object
#  29  is_translator                       396027 non-null  object
#  30  follow_request_sent                 396027 non-null  object
#  31  protected                           396027 non-null  object
#  32  verified                            396027 non-null  object
#  33  notifications                       396027 non-null  object
#  34  description                         396027 non-null  object
#  35  contributors_enabled                396027 non-null  object
#  36  following                           396027 non-null  object
#  37  updated_x                           396027 non-null  datetime64[ns]
#  38  timestamp_x                         200000 non-null  datetime64[ns]
#  39  crawled_at_x                        200000 non-null  datetime64[ns]
#  40  test_set_1                          396027 non-null  object
#  41  test_set_2                          396027 non-null  object
#  42  id                                  396027 non-null  float64
#  43  text                                396027 non-null  object
#  44  source                              396027 non-null  object
#  45  truncated                           396027 non-null  object
#  46  in_reply_to_status_id               396027 non-null  float64
#  47  in_reply_to_user_id                 396027 non-null  float64
#  48  in_reply_to_screen_name             396027 non-null  object
#  49  retweeted_status_id                 396027 non-null  object
#  50  geo                                 396027 non-null  object
#  51  place                               396027 non-null  object
#  52  contributors                        396027 non-null  object
#  53  retweet_count                       396027 non-null  float64
#  54  reply_count                         396027 non-null  float64
#  55  favorite_count                      396027 non-null  float64
#  56  favorited                           396027 non-null  object
#  57  retweeted                           396027 non-null  object
#  58  possibly_sensitive                  396027 non-null  object
#  59  num_hashtags                        396027 non-null  float64
#  60  num_urls                            396027 non-null  float64
#  61  num_mentions                        396027 non-null  float64
#  62  timestamp_y                         396027 non-null  datetime64[ns]
#  63  crawled_at_y                        200000 non-null  datetime64[ns]
#  64  updated_y                           200000 non-null  datetime64[ns]
#  65  account_age_days                    396027 non-null  float64
#  66  following_count                     396027 non-null  float64
#  67  post_frequency_per_day              396027 non-null  float64
#  68  avg_word_count_per_post             396027 non-null  float64
#  69  avg_hashtags_per_post               396027 non-null  float64
#  70  avg_sentiment_score                 396027 non-null  float64
#  71  reply_to_post_ratio                 396027 non-null  float64
#  72  urls_per_post_ratio                 396027 non-null  float64
#  73  bio_complexity_score                396027 non-null  float64
#  74  label                               396027 non-null  object
# dtypes: datetime64[ns](7), float64(24), object(44)
# memory usage: 226.6+ MB

# %%
from sklearn.preprocessing import LabelEncoder

# --- STEP 3: Feature Engineering & Encoding ---

# Encode booleans
for col in df.select_dtypes(include='bool').columns:
    df[col] = df[col].astype(int)

# Label encode binary categoricals
le = LabelEncoder()
binary_cols = [col for col in cat_cols if df[col].nunique() == 2 and df[col].dtype == 'object']  # Ensure dtype is 'object'

for col in binary_cols:
    df[col] = df[col].astype(str)  # Convert all values to strings before encoding
    df[col] = le.fit_transform(df[col])

# Create new features if needed
df['follower_friend_ratio'] = df['followers_count'] / (df['friends_count'] + 1)  # Avoid division by zero
df['tweet_like_ratio'] = df['favorite_count'] / (df['statuses_count'] + 1)       # Avoid division by zero

# Clean 'description' text (optional for later NLP)
import re

def clean_text(text):
    if pd.isna(text):
        return ''  # Handle NaN values
    text = re.sub(r"http\S+|www\S+|https\S+", '', text, flags=re.MULTILINE)  # Remove URLs
    text = re.sub(r'\@[\w]*', '', text)  # Remove mentions
    text = re.sub(r'[^A-Za-z\s]', '', text)  # Remove special characters
    text = text.lower()  # Convert text to lowercase
    return text

if 'description' in df.columns:
    df['description_clean'] = df['description'].apply(clean_text)

# %%
df.describe()
# Out:
#             user_id  statuses_count  followers_count  friends_count  \
# count  3.960270e+05   396027.000000    396027.000000  396027.000000
# mean   5.590412e+08     7332.904724      1250.312774    1047.095284
# min    6.780330e+05        0.000000         0.000000       0.000000
# 25%    1.936071e+08       79.000000        15.000000     266.000000
# 50%    4.663775e+08      819.000000       108.000000     543.000000
# 75%    6.162854e+08     4538.000000       614.000000     856.000000
# max    2.525273e+09   333504.000000    986837.000000   45690.000000
# std    5.530482e+08    20917.660182     16053.999812    2126.601939
#
#        favourites_count   listed_count                   created_at_x  \
# count     396027.000000  396027.000000                         396027
# mean        1499.677820      11.489015  2011-08-17 06:05:09.774954752
# min            0.000000       0.000000            2007-01-22 01:57:38
# 25%            0.000000       0.000000            2010-09-22 07:25:17
# 50%            1.000000       0.000000            2012-01-17 10:22:46
# 75%          255.000000       4.000000            2012-06-23 15:50:57
# max       185467.000000    4840.000000            2014-05-26 15:32:52
# std         6195.394558     104.203574                            NaN
#
#        default_profile  default_profile_image    geo_enabled  ...  \
# count    396027.000000          396027.000000  396027.000000  ...
# mean          0.592788               0.991836       0.682514  ...
# min           0.000000               0.000000       0.000000  ...
# 25%           0.000000               1.000000       0.000000  ...
# 50%           1.000000               1.000000       1.000000  ...
# 75%           1.000000               1.000000       1.000000  ...
# max           1.000000               1.000000       1.000000  ...
# std           0.491316               0.089983       0.465499  ...
#
#        post_frequency_per_day  avg_word_count_per_post  avg_hashtags_per_post  \
# count           396027.000000            396027.000000          396027.000000
# mean                25.069039                11.820992               0.203504
# min                  0.100007                 1.000000               0.000000
# 25%                 12.569980                 6.000000               0.000000
# 50%                 25.081000                11.000000               0.000000
# 75%                 37.559757                17.000000               0.000000
# max                 49.999811               142.000000              15.000000
# std                 14.423832                 7.024416               0.635895
#
#       avg_sentiment_score reply_to_post_ratio urls_per_post_ratio  \
# count       396027.000000       396027.000000       396027.000000
# mean             0.000664            0.017276            0.064007
# min             -0.999997            0.000000            0.000000
# 25%             -0.499444            0.000000            0.000000
# 50%              0.000866            0.000000            0.000000
# 75%              0.501908            0.000000            0.000000
# max              1.000000            0.941176            0.857143
# std              0.577775            0.091498            0.156614
#
#        bio_complexity_score          label  follower_friend_ratio  \
# count         396027.000000  396027.000000          396027.000000
# mean               0.499680       0.172400               2.602646
# min                0.000001       0.000000               0.000000
# 25%                0.249502       0.000000               0.040678
# 50%                0.499869       0.000000               0.239908
# 75%                0.750035       0.000000               0.941986
# max                1.000000       1.000000            2108.333333
# std                0.288648       0.377728              48.873745
#
#        tweet_like_ratio
# count     396027.000000
# mean           0.349150
# min            0.000000
# 25%            0.000000
# 50%            0.000000
# 75%            0.000000
# max         4665.482759
# std           25.210681
#
# [8 rows x 41 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 396027 entries, 0 to 396026
# Data columns (total 78 columns):
#  #   Column                              Non-Null Count   Dtype
# ---  ------                              --------------   -----
#  0   user_id                             396027 non-null  float64
#  1   name                                396027 non-null  object
#  2   screen_name                         396027 non-null  object
#  3   statuses_count                      396027 non-null  float64
#  4   followers_count                     396027 non-null  float64
#  5   friends_count                       396027 non-null  float64
#  6   favourites_count                    396027 non-null  float64
#  7   listed_count                        396027 non-null  float64
#  8   created_at_x                        396027 non-null  datetime64[ns]
#  9   url                                 396027 non-null  object
#  10  lang                                396027 non-null  object
#  11  time_zone                           396027 non-null  object
#  12  location                            396027 non-null  object
#  13  default_profile                     396027 non-null  int32
#  14  default_profile_image               396027 non-null  int32
#  15  geo_enabled                         396027 non-null  int32
#  16  profile_image_url                   396027 non-null  object
#  17  profile_banner_url                  396027 non-null  object
#  18  profile_use_background_image        396027 non-null  int32
#  19  profile_background_image_url_https  396027 non-null  object
#  20  profile_text_color                  396027 non-null  object
#  21  profile_image_url_https             396027 non-null  object
#  22  profile_sidebar_border_color        396027 non-null  object
#  23  profile_background_tile             396027 non-null  int32
#  24  profile_sidebar_fill_color          396027 non-null  object
#  25  profile_background_image_url        396027 non-null  object
#  26  profile_background_color            396027 non-null  object
#  27  profile_link_color                  396027 non-null  object
#  28  utc_offset                          396027 non-null  object
#  29  is_translator                       396027 non-null  object
#  30  follow_request_sent                 396027 non-null  object
#  31  protected                           396027 non-null  object
#  32  verified                            396027 non-null  int32
#  33  notifications                       396027 non-null  object
#  34  description                         396027 non-null  object
#  35  contributors_enabled                396027 non-null  object
#  36  following                           396027 non-null  object
#  37  updated_x                           396027 non-null  datetime64[ns]
#  38  timestamp_x                         200000 non-null  datetime64[ns]
#  39  crawled_at_x                        200000 non-null  datetime64[ns]
#  40  test_set_1                          396027 non-null  object
#  41  test_set_2                          396027 non-null  object
#  42  id                                  396027 non-null  float64
#  43  text                                396027 non-null  object
#  44  source                              396027 non-null  object
#  45  truncated                           396027 non-null  object
#  46  in_reply_to_status_id               396027 non-null  float64
#  47  in_reply_to_user_id                 396027 non-null  float64
#  48  in_reply_to_screen_name             396027 non-null  object
#  49  retweeted_status_id                 396027 non-null  object
#  50  geo                                 396027 non-null  object
#  51  place                               396027 non-null  object
#  52  contributors                        396027 non-null  object
#  53  retweet_count                       396027 non-null  float64
#  54  reply_count                         396027 non-null  float64
#  55  favorite_count                      396027 non-null  float64
#  56  favorited                           396027 non-null  object
#  57  retweeted                           396027 non-null  object
#  58  possibly_sensitive                  396027 non-null  int32
#  59  num_hashtags                        396027 non-null  float64
#  60  num_urls                            396027 non-null  float64
#  61  num_mentions                        396027 non-null  float64
#  62  timestamp_y                         396027 non-null  datetime64[ns]
#  63  crawled_at_y                        200000 non-null  datetime64[ns]
#  64  updated_y                           200000 non-null  datetime64[ns]
#  65  account_age_days                    396027 non-null  float64
#  66  following_count                     396027 non-null  float64
#  67  post_frequency_per_day              396027 non-null  float64
#  68  avg_word_count_per_post             396027 non-null  float64
#  69  avg_hashtags_per_post               396027 non-null  float64
#  70  avg_sentiment_score                 396027 non-null  float64
#  71  reply_to_post_ratio                 396027 non-null  float64
#  72  urls_per_post_ratio                 396027 non-null  float64
#  73  bio_complexity_score                396027 non-null  float64
#  74  label                               396027 non-null  int32
#  75  follower_friend_ratio               396027 non-null  float64
#  76  tweet_like_ratio                    396027 non-null  float64
#  77  description_clean                   396027 non-null  object
# dtypes: datetime64[ns](7), float64(26), int32(8), object(37)
# memory usage: 223.6+ MB

# %%
# --- STEP 4: Drop Unnecessary or Redundant Columns ---

# Step 1: Automatically drop low-variance columns
low_variance_cols = [col for col in df.columns if df[col].nunique() <= 1]

# Step 2: Manually drop identifiers or redundant features (images, URLs)
manual_drop_cols = [
    'user_id', 'profile_image_url', 'profile_banner_url',
    'profile_background_image_url', 'profile_background_image_url_https',
    'profile_image_url_https', 'url', 'source'
]

# Step 3: Optional: Drop high cardinality identifiers (if not used in NLP)
# If you plan to use name/screen_name in feature engineering, keep them
identifier_cols = ['name', 'screen_name']

# Combine and drop
final_drop_cols = low_variance_cols + manual_drop_cols  # + identifier_cols (optional)
df.drop(columns=[col for col in final_drop_cols if col in df.columns], inplace=True)

print("Dropped columns:", final_drop_cols)
# Out:
# Dropped columns: ['is_translator', 'follow_request_sent', 'protected', 'notifications', 'contributors_enabled', 'following', 'truncated', 'geo', 'contributors', 'favorited', 'retweeted', 'user_id', 'profile_image_url', 'profile_banner_url', 'profile_background_image_url', 'profile_background_image_url_https', 'profile_image_url_https', 'url', 'source']

# %%
low_variance_cols = [col for col in df.columns if df[col].nunique() <= 1]

low_variance_cols
# Out:
# []

# %%
# --- STEP 5: Prepare Features and Labels ---
target_col = 'label'
X = df.drop(columns=[target_col])  # Features
y = df[target_col].astype(int)     # Target labels

# %%
# --- Optional Scaling ---
scaler = StandardScaler()
X_scaled = pd.DataFrame(scaler.fit_transform(X.select_dtypes(include=['float64', 'int64'])), 
                        columns=X.select_dtypes(include=['float64', 'int64']).columns)

# Reattach non-scaled features (categoricals etc.)
X_final = pd.concat([X_scaled, X.drop(columns=X_scaled.columns)], axis=1)

# --- Train/Test Split ---
X_train, X_test, y_train, y_test = train_test_split(X_final, y, test_size=0.2, random_state=42, stratify=y)

print("Data cleaned and ready! Shapes:", X_train.shape, X_test.shape)
# Out:
# Data cleaned and ready! Shapes: (316821, 58) (79206, 58)

# %%
X_train.columns
# Out:
# Index(['statuses_count', 'followers_count', 'friends_count',
#        'favourites_count', 'listed_count', 'id', 'in_reply_to_status_id',
#        'in_reply_to_user_id', 'retweet_count', 'reply_count', 'favorite_count',
#        'num_hashtags', 'num_urls', 'num_mentions', 'account_age_days',
#        'following_count', 'post_frequency_per_day', 'avg_word_count_per_post',
#        'avg_hashtags_per_post', 'avg_sentiment_score', 'reply_to_post_ratio',
#        'urls_per_post_ratio', 'bio_complexity_score', 'follower_friend_ratio',
#        'tweet_like_ratio', 'name', 'screen_name', 'created_at_x', 'lang',
#        'time_zone', 'location', 'default_profile', 'default_profile_image',
#        'geo_enabled', 'profile_use_background_image', 'profile_text_color',
#        'profile_sidebar_border_color', 'profile_background_tile',
#        'profile_sidebar_fill_color', 'profile_background_color',
#        'profile_link_color', 'utc_offset', 'verified', 'description',
#        'updated_x', 'timestamp_x', 'crawled_at_x', 'test_set_1', 'test_set_2',
#        'text', 'in_reply_to_screen_name', 'retweeted_status_id', 'place',
#        'possibly_sensitive', 'timestamp_y', 'crawled_at_y', 'updated_y',
#        'description_clean'],
#       dtype='object')

# %%
X_test.columns
# Out:
# Index(['statuses_count', 'followers_count', 'friends_count',
#        'favourites_count', 'listed_count', 'id', 'in_reply_to_status_id',
#        'in_reply_to_user_id', 'retweet_count', 'reply_count', 'favorite_count',
#        'num_hashtags', 'num_urls', 'num_mentions', 'account_age_days',
#        'following_count', 'post_frequency_per_day', 'avg_word_count_per_post',
#        'avg_hashtags_per_post', 'avg_sentiment_score', 'reply_to_post_ratio',
#        'urls_per_post_ratio', 'bio_complexity_score', 'follower_friend_ratio',
#        'tweet_like_ratio', 'name', 'screen_name', 'created_at_x', 'lang',
#        'time_zone', 'location', 'default_profile', 'default_profile_image',
#        'geo_enabled', 'profile_use_background_image', 'profile_text_color',
#        'profile_sidebar_border_color', 'profile_background_tile',
#        'profile_sidebar_fill_color', 'profile_background_color',
#        'profile_link_color', 'utc_offset', 'verified', 'description',
#        'updated_x', 'timestamp_x', 'crawled_at_x', 'test_set_1', 'test_set_2',
#        'text', 'in_reply_to_screen_name', 'retweeted_status_id', 'place',
#        'possibly_sensitive', 'timestamp_y', 'crawled_at_y', 'updated_y',
#        'description_clean'],
#       dtype='object')

# %%
y_train.name
# Out:
# 'label'

# %%
y_test.name
# Out:
# 'label'

# %%
# STEP 6A: Target Distribution
plt.figure(figsize=(6, 4))
sns.countplot(x='label', data=df)
plt.title('Distribution of Bot vs Human Accounts')
plt.xlabel('Label (0 = Human, 1 = Bot)')
plt.ylabel('Count')
plt.show()

print(df['label'].value_counts(normalize=True).rename('proportion'))
# Out:
# label
# 0    0.8276
# 1    0.1724
# Name: proportion, dtype: float64

# %%
#STEP 6B: Correlation Heatmap (Numerics Only)

# Select numeric features only
numeric_df = df.select_dtypes(include=[np.number])

# Optional: Drop ID columns or unrelated large-scale IDs if left
corr = numeric_df.corr()

plt.figure(figsize=(14, 10))
sns.heatmap(corr, cmap='coolwarm', annot=False, linewidths=0.5)
plt.title("Feature Correlation Heatmap")
plt.show()

# %%
# STEP 6C: Feature Distributions (Bots vs Humans)

# Ensure the target column is included in X_train for analysis
X_train['label'] = y_train  # Attach labels back for visualization

bot_df = X_train[X_train['label'] == 1]  # Bots
human_df = X_train[X_train['label'] == 0]  # Humans

# Select features to visualize
top_feats = ['followers_count', 'friends_count', 'statuses_count', 
             'favourites_count', 'listed_count']

plt.figure(figsize=(15, 10))
for i, feat in enumerate(top_feats):
    if feat in X_train.columns:  # Check if feature exists
        plt.subplot(2, 3, i + 1)
        sns.kdeplot(bot_df[feat], label='Bot', fill=True)
        sns.kdeplot(human_df[feat], label='Human', fill=True)
        plt.title(f'Distribution of {feat}')
        plt.legend()
plt.tight_layout()
plt.show()

# %%
# STEP 6D: Top Words in Descriptions (TF-IDF)

# Fill NA
df['description'] = df['description'].fillna("")

# Vectorize description
vectorizer = TfidfVectorizer(max_features=100, stop_words='english')
tfidf_matrix = vectorizer.fit_transform(df['description'])
tfidf_df = pd.DataFrame(tfidf_matrix.toarray(), columns=vectorizer.get_feature_names_out())

# Top words for bots
bot_tfidf = tfidf_df[df['label'] == 1].mean().sort_values(ascending=False).head(20)

# Top words for humans
human_tfidf = tfidf_df[df['label'] == 0].mean().sort_values(ascending=False).head(20)

plt.figure(figsize=(10, 4))
bot_tfidf.plot(kind='barh', title='Top TF-IDF Words in Bot Descriptions')
plt.gca().invert_yaxis()
plt.show()

plt.figure(figsize=(10, 4))
human_tfidf.plot(kind='barh', title='Top TF-IDF Words in Human Descriptions')
plt.gca().invert_yaxis()
plt.show()

# %%
#STEP 7: Feature Engineering

from sklearn.preprocessing import LabelEncoder

# Fill missing values
X_train['description_clean'] = X_train['description_clean'].fillna('')
X_test['description_clean'] = X_test['description_clean'].fillna('')
X_train['location'] = X_train['location'].fillna('unknown')
X_test['location'] = X_test['location'].fillna('unknown')

# Encode categorical columns safely using mapping
cat_cols = ['lang', 'time_zone', 'location']
le_dict = {}

for col in cat_cols:
    le = LabelEncoder()
    X_train[col] = le.fit_transform(X_train[col].astype(str))
    
    # Build mapping dictionary
    mapping = dict(zip(le.classes_, le.transform(le.classes_)))
    
    # Map test values, use -1 for unknown categories
    X_test[col] = X_test[col].astype(str).map(mapping).fillna(-1).astype(int)
    
    le_dict[col] = le

# %%
tfidf = TfidfVectorizer(max_features=100, stop_words='english')

X_desc_train = tfidf.fit_transform(X_train['description_clean']).toarray()
X_desc_test = tfidf.transform(X_test['description_clean']).toarray()

# Drop original text column
X_train.drop(columns=['description_clean'], inplace=True)
X_test.drop(columns=['description_clean'], inplace=True)

# Add TF-IDF features
tfidf_cols = [f'tfidf_{i}' for i in range(X_desc_train.shape[1])]
X_train_tfidf = pd.DataFrame(X_desc_train, columns=tfidf_cols, index=X_train.index)
X_test_tfidf = pd.DataFrame(X_desc_test, columns=tfidf_cols, index=X_test.index)

X_train = pd.concat([X_train, X_train_tfidf], axis=1)
X_test = pd.concat([X_test, X_test_tfidf], axis=1)

# %%
# Reload
df = pd.read_csv(r"C:\Users\Lokesh Patra\Documents\Projects\Major Project\cresci-2017.csv\cresci-2017\sytnth\final_dataset.csv", low_memory=False)

# STEP 2: Preprocess and split
df['description_clean'] = df['description'].fillna('')
df['location'] = df['location'].fillna('unknown')

X = df.drop(columns=['label', 'id'], errors='ignore')
y = df['label']

X_train, X_test, y_train, y_test = train_test_split(X.copy(), y.copy(), test_size=0.2, random_state=42)

# %%
# Encode Categorical Features
cat_cols = ['lang', 'time_zone', 'location']
le_dict = {}

for col in cat_cols:
    le = LabelEncoder()
    X_train[col] = le.fit_transform(X_train[col].astype(str))
    
    # Mapping test set manually
    mapping = dict(zip(le.classes_, le.transform(le.classes_)))
    X_test[col] = X_test[col].astype(str).map(mapping).fillna(-1).astype(int)
    
    le_dict[col] = le

# %%
# TF-IDF for description_re clean
tfidf = TfidfVectorizer(max_features=100, stop_words='english')
X_desc_train = tfidf.fit_transform(X_train['description_clean']).toarray()
X_desc_test = tfidf.transform(X_test['description_clean']).toarray()

# Drop original text column
X_train.drop(columns=['description_clean'], inplace=True)
X_test.drop(columns=['description_clean'], inplace=True)

# Re-adding TF-IDF vectors
tfidf_cols = [f'tfidf_{i}' for i in range(X_desc_train.shape[1])]
X_train_tfidf = pd.DataFrame(X_desc_train, columns=tfidf_cols, index=X_train.index)
X_test_tfidf = pd.DataFrame(X_desc_test, columns=tfidf_cols, index=X_test.index)

X_train = pd.concat([X_train, X_train_tfidf], axis=1)
X_test = pd.concat([X_test, X_test_tfidf], axis=1)

# %%
# Debug: Check for any non-numeric columns before training
non_numeric_cols = X_train.select_dtypes(include=['object']).columns

non_numeric_cols.tolist()

X_train[non_numeric_cols].head()

# Drop or encode any remaining non-numeric columns
X_train.drop(columns=non_numeric_cols, inplace=True)
X_test.drop(columns=non_numeric_cols, inplace=True)

# %%
# STEP 5: Model Setup

rf = RandomForestClassifier(n_estimators=100, random_state=42)
gb = HistGradientBoostingClassifier()  # Handles NaNs

ensemble = VotingClassifier(estimators=[('rf', rf), ('gb', gb)], voting='soft')
ensemble.fit(X_train, y_train)
# Out:
# VotingClassifier(estimators=[('rf', RandomForestClassifier(random_state=42)),
#                              ('gb', HistGradientBoostingClassifier())],
#                  voting='soft')

# %%
# STEP 7: Evaluation
y_pred = ensemble.predict(X_test)
y_proba = ensemble.predict_proba(X_test)  # Assuming your model supports predict_proba

# Classification Report and Confusion Matrix
print("\nClassification Report:\n", classification_report(y_test, y_pred))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred))

# Basic Scores
print(f"\nAccuracy: {(accuracy_score(y_test, y_pred)) * 100:.2f}%")
print(f"Precision (bot): {precision_score(y_test, y_pred, pos_label='bot'):.2f}")
print(f"Recall (bot): {recall_score(y_test, y_pred, pos_label='bot'):.2f}")
print(f"F1 Score (bot): {f1_score(y_test, y_pred, pos_label='bot'):.2f}")

# ROC-AUC Score (for binary classification only)
# Binarize the string labels
y_test_bin = label_binarize(y_test, classes=['human', 'bot'])  # 0 for human, 1 for bot
print(f"ROC-AUC Score: {roc_auc_score(y_test_bin, y_proba[:, 1]):.2f}")
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#          bot       1.00      1.00      1.00     65526
#        human       1.00      1.00      1.00     13680
#
#     accuracy                           1.00     79206
#    macro avg       1.00      1.00      1.00     79206
# weighted avg       1.00      1.00      1.00     79206
#
#
# Confusion Matrix:
#  [[65524     2]
#  [   11 13669]]
#
# Accuracy: 99.98%
# Precision (bot): 1.00
# Recall (bot): 1.00
# F1 Score (bot): 1.00
# ROC-AUC Score: 0.00

# %%
# Convert string labels to binary: bot=1, human=0
from sklearn.preprocessing import LabelBinarizer
from sklearn.metrics import roc_curve, auc

# Binarize the labels
lb = LabelBinarizer()
y_test_bin = lb.fit_transform(y_test).ravel()

# Predict probabilities
y_score = ensemble.predict_proba(X_test)[:, 1]

# Compute ROC curve and AUC
fpr, tpr, _ = roc_curve(y_test_bin, y_score, pos_label=1)
roc_auc = auc(fpr, tpr)

# Plot
plt.figure(figsize=(6,4))
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = {:.2f})'.format(roc_auc))
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()

# %%
# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap="Blues", xticklabels=["Human", "Bot"], yticklabels=["Human", "Bot"])
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# %%
# Extract the gradient boosting model
gb_model = ensemble.named_estimators_['gb']

# Create SHAP explainer and compute values
explainer = shap.Explainer(gb_model.predict, X_test)  # for faster approximation
shap_values = explainer(X_test)

# Summary plot
shap.summary_plot(shap_values, X_test, plot_type="bar")
# Out:
# PermutationExplainer explainer:   2%|▏         | 1262/79206 [02:14<2:18:38,  9.37it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[32], line 6
#       4 # Create SHAP explainer and compute values
#       5 explainer = shap.Explainer(gb_model.predict, X_test)  # for faster approximation
# ----> 6 shap_values = explainer(X_test)
#       8 # Summary plot
#       9 shap.summary_plot(shap_values, X_test, plot_type="bar")
#
# File c:\Users\Lokesh Patra\AppData\Local\Programs\Python\Python312\Lib\site-packages\shap\explainers\_permutation.py:100, in PermutationExplainer.__call__(self, max_evals, main_effects, error_bounds, batch_size, outputs, silent, *args)
#      89 def __call__(
#      90     self,
#      91     *args,
#    (...)
#      97     silent=False,
#      98 ):
#      99     """Explain the output of the model on the given arguments."""
# --> 100     return super().__call__(
#     101         *args,
#     102         max_evals=max_evals,
#     103         main_effects=main_effects,
#     104         error_bounds=error_bounds,
#     105         batch_size=batch_size,
#     106         outputs=outputs,
#     107         silent=silent,
#     108     )
#
# File c:\Users\Lokesh Patra\AppData\Local\Programs\Python\Python312\Lib\site-packages\shap\explainers\_explainer.py:366, in Explainer.__call__(self, max_evals, main_effects, error_bounds, batch_size, outputs, silent, *args, **kwargs)
#     364     feature_names = [[] for _ in range(len(args))]
#     365 for row_args in show_progress(zip(*args), num_rows, self.__class__.__name__ + " explainer", silent):
# --> 366     row_result = self.explain_row(
#     367         *row_args,
#     368         max_evals=max_evals,
#     369         main_effects=main_effects,
#     370         error_bounds=error_bounds,
#     371         batch_size=batch_size,
#     372         outputs=outputs,
#     373         silent=silent,
#     374         **kwargs,
#     375     )
#     376     values.append(row_result.get("values", None))
#     377     output_indices.append(row_result.get("output_indices", None))
#
# File c:\Users\Lokesh Patra\AppData\Local\Programs\Python\Python312\Lib\site-packages\shap\explainers\_permutation.py:200, in PermutationExplainer.explain_row(self, max_evals, main_effects, error_bounds, batch_size, outputs, silent, *row_args)
#     198     # compute the main effects if we need to
#     199     if main_effects:
# --> 200         main_effect_values = fm.main_effects(inds, batch_size=batch_size)
#     201 else:
#     202     masks = np.zeros(1, dtype=int)
#
# File c:\Users\Lokesh Patra\AppData\Local\Programs\Python\Python312\Lib\site-packages\shap\utils\_masked_model.py:270, in MaskedModel.main_effects(self, inds, batch_size)
#     267     last_ind = inds[i]
#     269 # compute the main effects for the given indexes
# --> 270 outputs = self(masks, batch_size=batch_size)
#     271 main_effects = outputs[1:] - outputs[0]
#     273 # expand the vector to the full input size
#
# File c:\Users\Lokesh Patra\AppData\Local\Programs\Python\Python312\Lib\site-packages\shap\utils\_masked_model.py:57, in MaskedModel.__call__(self, masks, zero_index, batch_size)
#      55 if len(masks.shape) == 1:
#      56     if getattr(self.masker, "supports_delta_masking", False):
# ---> 57         return self._delta_masking_call(masks, zero_index=zero_index, batch_size=batch_size)
#      59     # we need to convert from delta masking to a full masking call because we were given a delta masking
#      60     # input but the masker does not support delta masking
#      61     else:
#      62         full_masks = np.zeros((int(np.sum(masks >= 0)), self._masker_cols), dtype=bool)
#
# File c:\Users\Lokesh Patra\AppData\Local\Programs\Python\Python312\Lib\site-packages\shap\utils\_masked_model.py:199, in MaskedModel._delta_masking_call(self, masks, zero_index, batch_size)
#     194 def _delta_masking_call(self, masks, zero_index=None, batch_size=None):
#     195     # TODO: we need to do batching here
#     197     assert getattr(self.masker, "supports_delta_masking", None) is not None, "Masker must support delta masking!"
# --> 199     masked_inputs, varying_rows = self.masker(masks, *self.args)
#     200     num_varying_rows = varying_rows.sum(1)
#     202     subset_masked_inputs = [arg[varying_rows.reshape(-1)] for arg in masked_inputs]
#
# File c:\Users\Lokesh Patra\AppData\Local\Programs\Python\Python312\Lib\site-packages\shap\maskers\_tabular.py:101, in Tabular.__call__(self, mask, x)
#      99 # if mask is an array of integers then we are doing delta masking
#     100 if np.issubdtype(mask.dtype, np.integer):
# --> 101     variants = ~self.invariants(x)
#     102     curr_delta_inds = np.zeros(len(mask), dtype=int)
#     103     num_masks = (mask >= 0).sum()
#
# File c:\Users\Lokesh Patra\AppData\Local\Programs\Python\Python312\Lib\site-packages\shap\maskers\_tabular.py:158, in Tabular.invariants(self, x)
#     149 if x.shape != self.data.shape[1:]:
#     150     raise DimensionError(
#     151         "The passed data does not match the background shape expected by the masker! The data of shape "
#     152         + str(x.shape)
#    (...)
#     155         + "."
#     156     )
# --> 158 return np.isclose(x, self.data)
#
# File c:\Users\Lokesh Patra\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\core\numeric.py:2349, in isclose(a, b, rtol, atol, equal_nan)
#    2346     y = asanyarray(y, dtype=dt)
#    2348 xfin = isfinite(x)
# -> 2349 yfin = isfinite(y)
#    2350 if all(xfin) and all(yfin):
#    2351     return within_tol(x, y, atol, rtol)
#
# KeyboardInterrupt:
